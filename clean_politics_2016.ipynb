# %%
import pandas as pd
geopolitics_file = "Resources/US_County_Level_Presidential_Results_12-16.csv"

geopolitics_df = pd.read_csv(geopolitics_file)

# %%
geopolitics_df.head()
# Out:
#    Unnamed: 0  combined_fips  votes_dem_2016  votes_gop_2016  \
# 0           0           2013         93003.0        130413.0
# 1           1           2016         93003.0        130413.0
# 2           2           2020         93003.0        130413.0
# 3           3           2050         93003.0        130413.0
# 4           4           2060         93003.0        130413.0
#
#    total_votes_2016  per_dem_2016  per_gop_2016  diff_2016  \
# 0          246588.0      0.377159       0.52887      37410
# 1          246588.0      0.377159       0.52887      37410
# 2          246588.0      0.377159       0.52887      37410
# 3          246588.0      0.377159       0.52887      37410
# 4          246588.0      0.377159       0.52887      37410
#
#    per_point_diff_2016 state_abbr  ...  FIPS  total_votes_2012  \
# 0            -0.151711         AK  ...  2013               NaN
# 1            -0.151711         AK  ...  2016               NaN
# 2            -0.151711         AK  ...  2020               NaN
# 3            -0.151711         AK  ...  2050               NaN
# 4            -0.151711         AK  ...  2060               NaN
#
#    votes_dem_2012  votes_gop_2012  county_fips  state_fips  per_dem_2012  \
# 0             NaN             NaN          NaN         NaN           NaN
# 1             NaN             NaN          NaN         NaN           NaN
# 2             NaN             NaN          NaN         NaN           NaN
# 3             NaN             NaN          NaN         NaN           NaN
# 4             NaN             NaN          NaN         NaN           NaN
#
#    per_gop_2012  diff_2012  per_point_diff_2012
# 0           NaN        NaN                  NaN
# 1           NaN        NaN                  NaN
# 2           NaN        NaN                  NaN
# 3           NaN        NaN                  NaN
# 4           NaN        NaN                  NaN
#
# [5 rows x 21 columns]

# %%
geopolitics_df.shape
# Out:
# (3141, 5)

# %%
geopolitics_df_duplicates_removed = pd.DataFrame.drop_duplicates(geopolitics_df)

# %%
clean_politics_2016_df = pd.DataFrame(geopolitics_df_duplicates_removed)

# %%
clean_politics_2016_df
# Out:
#       votes_dem_2016  votes_gop_2016  total_votes_2016 state_abbr  \
# 0            93003.0        130413.0          246588.0         AK
# 29            5908.0         18110.0           24661.0         AL
# 30           18409.0         72780.0           94090.0         AL
# 31            4848.0          5431.0           10390.0         AL
# 32            1874.0          6733.0            8748.0         AL
# ...              ...             ...               ...        ...
# 3136          3233.0         12153.0           16661.0         WY
# 3137          7313.0          3920.0           12176.0         WY
# 3138          1202.0          6154.0            8053.0         WY
# 3139           532.0          2911.0            3715.0         WY
# 3140           294.0          2898.0            3334.0         WY
#
#             county_name
# 0                Alaska
# 29       Autauga County
# 30       Baldwin County
# 31       Barbour County
# 32          Bibb County
# ...                 ...
# 3136  Sweetwater County
# 3137       Teton County
# 3138       Uinta County
# 3139    Washakie County
# 3140      Weston County
#
# [3113 rows x 5 columns]

# %%
clean_politics_2016_df.duplicated()
# Out:
# 0       False
# 29      False
# 30      False
# 31      False
# 32      False
#         ...
# 3136    False
# 3137    False
# 3138    False
# 3139    False
# 3140    False
# Length: 3113, dtype: bool
