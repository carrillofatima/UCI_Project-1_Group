# %%
import pandas as pd
import numpy as np

#  csv file to red data from
census_est_19 = "Resources/pop_est19.csv"
keyfile = "Resources/state_abbr list.csv"
geopolitics_file = "Resources/2016_US_County_Level_Presidential_Results.csv"
#covid_total_data = "Resources/final_data_per_state.csv"

# Read state total population into DF
census_df = pd.read_csv(census_est_19)

# Read state abbr into DF
key_abbr_state_df = pd.read_csv(keyfile)

# read covid total deaths as of Ovt. 20th
# total_deaths_by_state_df = pd.read_csv(covid_total_data)

# read in election results per state for 2016b election
presidential_results_2016_df = pd.read_csv(geopolitics_file)

# %%
census_df.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'NAME', 'POPESTIMATE2019',
#        'POPEST18PLUS2019', 'PCNT_POPEST18PLUS'],
#       dtype='object')

# %%
#census_df.drop(census_df["SUMLEV", "REGION", "DIVISION", "STATE", "POPEST18PLUS2019", "PCNT_POPEST18PLUS"], inplace=True)new_census_
new_census = census_df[["NAME", "POPESTIMATE2019"]]
new_census_df = pd.DataFrame(new_census)

new_census_df
# Out:
#                         NAME  POPESTIMATE2019
# 0              United States        328239523
# 1                    Alabama          4903185
# 2                     Alaska           731545
# 3                    Arizona          7278717
# 4                   Arkansas          3017804
# 5                 California         39512223
# 6                   Colorado          5758736
# 7                Connecticut          3565287
# 8                   Delaware           973764
# 9       District of Columbia           705749
# 10                   Florida         21477737
# 11                   Georgia         10617423
# 12                    Hawaii          1415872
# 13                     Idaho          1787065
# 14                  Illinois         12671821
# 15                   Indiana          6732219
# 16                      Iowa          3155070
# 17                    Kansas          2913314
# 18                  Kentucky          4467673
# ...

# %%
census_2019_df = new_census_df.rename(columns={"POPESTIMATE2019":"Estimated Population 2019"})
census_2019_df
# Out:
#                         NAME  Estimated Population 2019
# 0              United States                  328239523
# 1                    Alabama                    4903185
# 2                     Alaska                     731545
# 3                    Arizona                    7278717
# 4                   Arkansas                    3017804
# 5                 California                   39512223
# 6                   Colorado                    5758736
# 7                Connecticut                    3565287
# 8                   Delaware                     973764
# 9       District of Columbia                     705749
# 10                   Florida                   21477737
# 11                   Georgia                   10617423
# 12                    Hawaii                    1415872
# 13                     Idaho                    1787065
# 14                  Illinois                   12671821
# 15                   Indiana                    6732219
# ...

# %%
#census_2019_df.drop(census_2019_df[census_2019_df['NAME'] == United States], inplace=True)

# %%
narrow_key_abbr = key_abbr_state_df.reset_index()
narrow_key_abbr_df = pd.DataFrame(narrow_key_abbr)
narrow_key_abbr_df
# Out:
#     index                     state state_abbr
# 0       0                   Alabama         AL
# 1       1                    Alaska         AK
# 2       2                   Arizona         AZ
# 3       3                  Arkansas         AR
# 4       4                California         CA
# 5       5                  Colorado         CO
# 6       6               Connecticut         CT
# 7       7                  Delaware         DE
# 8       8      District of Columbia         DC
# 9       9                   Florida         FL
# 10     10                   Georgia         GA
# 11     11                    Hawaii         HI
# 12     12                     Idaho         ID
# 13     13                  Illinois         IL
# 14     14                   Indiana         IN
# 15     15                      Iowa         IA
# 16     16                    Kansas         KS
# 17     17                  Kentucky         KY
# 18     18                 Louisiana         LA
# ...

# %%
census_2019_df
# Out:
#                         NAME  Estimated Population 2019
# 0              United States                  328239523
# 1                    Alabama                    4903185
# 2                     Alaska                     731545
# 3                    Arizona                    7278717
# 4                   Arkansas                    3017804
# 5                 California                   39512223
# 6                   Colorado                    5758736
# 7                Connecticut                    3565287
# 8                   Delaware                     973764
# 9       District of Columbia                     705749
# 10                   Florida                   21477737
# 11                   Georgia                   10617423
# 12                    Hawaii                    1415872
# 13                     Idaho                    1787065
# 14                  Illinois                   12671821
# 15                   Indiana                    6732219
# ...

# %%
renamed_census_2019_df = census_2019_df.rename(columns={"NAME":"state"})
renamed_census_2019_df
# Out:
#                        state  Estimated Population 2019
# 0              United States                  328239523
# 1                    Alabama                    4903185
# 2                     Alaska                     731545
# 3                    Arizona                    7278717
# 4                   Arkansas                    3017804
# 5                 California                   39512223
# 6                   Colorado                    5758736
# 7                Connecticut                    3565287
# 8                   Delaware                     973764
# 9       District of Columbia                     705749
# 10                   Florida                   21477737
# 11                   Georgia                   10617423
# 12                    Hawaii                    1415872
# 13                     Idaho                    1787065
# 14                  Illinois                   12671821
# 15                   Indiana                    6732219
# ...

# %%
states_population_2019_merge_df = pd.merge(narrow_key_abbr_df, renamed_census_2019_df, on="state", how="left")
states_population_2019_merge_df.set_index(["state_abbr"], inplace=True, append=True)
states_population_2019_merge_df
# Out:
#                index                     state  Estimated Population 2019
#    state_abbr
# 0  AL              0                   Alabama                  4903185.0
# 1  AK              1                    Alaska                   731545.0
# 2  AZ              2                   Arizona                  7278717.0
# 3  AR              3                  Arkansas                  3017804.0
# 4  CA              4                California                 39512223.0
# 5  CO              5                  Colorado                  5758736.0
# 6  CT              6               Connecticut                  3565287.0
# 7  DE              7                  Delaware                   973764.0
# 8  DC              8      District of Columbia                   705749.0
# 9  FL              9                   Florida                 21477737.0
# 10 GA             10                   Georgia                 10617423.0
# ...

# %%
#clean_states_population_2019 = states_population_2019_merge_df.dropna()
#clean_states_populations_2019_df = pd.DataFrame(clean_states_population_2019)
#clean_states_populations_2019_df

# %%
#best_state_df = clean_states_populations_2019_df.set_index(["state_abbr"], inplace=True)
#clean_states_populations_2019_df.set_index(['state_abbr'], inplace=True)
#clean_states_populations_2019_df

# %%
states_population_2019_merge_df.count()
# Out:
# index                        56
# state                        56
# Estimated Population 2019    51
# dtype: int64

# %%
#clean_states_populations_2019_df[total_deaths_Jan20_Oct20] = ""
narrow_final_state = states_population_2019_merge_df.dropna()
narrow_final_state_df = pd.DataFrame(narrow_final_state)
narrow_final_state_df
# Out:
#                index                 state  Estimated Population 2019
#    state_abbr
# 0  AL              0               Alabama                  4903185.0
# 1  AK              1                Alaska                   731545.0
# 2  AZ              2               Arizona                  7278717.0
# 3  AR              3              Arkansas                  3017804.0
# 4  CA              4            California                 39512223.0
# 5  CO              5              Colorado                  5758736.0
# 6  CT              6           Connecticut                  3565287.0
# 7  DE              7              Delaware                   973764.0
# 8  DC              8  District of Columbia                   705749.0
# 9  FL              9               Florida                 21477737.0
# 10 GA             10               Georgia                 10617423.0
# 11 HI             11                Hawaii                  1415872.0
# ...

# %%
state_populations = narrow

# %%
# Read in total deaths per state as of October 19th, 2020
keyfile = "Resources/state_abbr list.csv"
key_abbr_state_df = pd.read_csv(keyfile)

death_file = "Resources/final_death_per_state.csv"
covid_death_total = pd.read_csv(death_file)
covid_death_file_df = pd.DataFrame(covid_death_total)
covid_death_file_df.head()
# Out:
#         state  Total Deaths from January 2020 to October 2020
# 0     Alabama                                            2789
# 1      Alaska                                              63
# 2     Arizona                                            5830
# 3    Arkansas                                            1714
# 4  California                                           16987

# %%
# ceate dataframe that has the total number of deaths per state, which lasted from 01/21/2020 through 10/20/2020
covid_death_abbr_merged_df = pd.merge(key_abbr_state_df, covid_death_file_df, on="state", how="left")
#clean_covid_death_state_abbr_df = covid_death_abbr_merged_df.dropna()
#clean_covid_death_state_abbr_df 
total_state_deaths = covid_death_abbr_merged_df.dropna()
total_state_deaths_df = pd.DataFrame(total_state_deaths)
total_state_deaths_df
# Out:
#              state state_abbr  Total Deaths from January 2020 to October 2020
# 0          Alabama         AL                                          2789.0
# 1           Alaska         AK                                            63.0
# 2          Arizona         AZ                                          5830.0
# 3         Arkansas         AR                                          1714.0
# 4       California         CA                                         16987.0
# 5         Colorado         CO                                          2207.0
# 6      Connecticut         CT                                          4554.0
# 7         Delaware         DE                                           666.0
# 9          Florida         FL                                         16020.0
# 10         Georgia         GA                                          7479.0
# 11          Hawaii         HI                                           186.0
# ...

# %%
per_capita_deaths_merged_df = pd.merge
(total_state_deaths_df["Total Deaths from January 2020 to October 2020"] / (narrow_final_state_df["Estimated Population 2019"]*100), on="state", how="left")

per_capita_deaths_merged_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-310-026aca18dc9e> in <module>
# ----> 1 per_capita_deaths_merged_df = pd.join(total_state_deaths_df["Total Deaths from January 2020 to October 2020"] / (narrow_final_state_df["Estimated Population 2019"]*100), on="state", how="left")
#       2
#       3 per_capita_deaths_merged_df
#
# AttributeError: module 'pandas' has no attribute 'join'

# %%
output_data = "Resources/total_deaths_gf.csv"
total_state_deaths_df.to_csv(output_data)

# %%
output_data = "Resources/total_population_gf.csv"
narrow_final_state_df.to_csv(output_data)

# %%
# per capita = measurement / number of people in a population
total_death = ["Total Deaths from January 2020 to October 2020"]
total_population = ["Estimated Population 2019"]
deaths_per_capita = ["Total Deaths from January 2020 to October 2020"] / ["Estimated Population 2019"]*100)")
total_state_deaths_df[deaths_per_capita]
# Out:
#   File "<ipython-input-306-27a066e681e4>", line 4
#     deaths_per_capita = ["Total Deaths from January 2020 to October 2020"] / ["Estimated Population 2019"]*100)")
#                                                                                                               ^
# SyntaxError: invalid syntax

# %%
df['total_deaths'] state_deaths_per_capita = ((total_deaths / total_population) * 100000)
