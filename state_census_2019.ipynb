# %%
import pandas as pd
import numpy as np

#  csv file to read data from
census_est_19 = "Resources/pop_est19.csv"

census_df = pd.read_csv(census_est_19)

# %%
census_df.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'NAME', 'POPESTIMATE2019',
#        'POPEST18PLUS2019', 'PCNT_POPEST18PLUS'],
#       dtype='object')

# %%
narrow_census_df = census_df.drop(['SUMLEV', 'REGION', 'DIVISION', 'STATE',  'POPEST18PLUS2019', 'PCNT_POPEST18PLUS'], axis=1, inplace=True)

# %%
narrow_census_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-9326b3070184> in <module>
# ----> 1 narrow_census_df.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
census_narrow_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-58eeff256d91> in <module>
# ----> 1 census_narrow_df.head()
#
# NameError: name 'census_narrow_df' is not defined

# %%
census_df
# Out:
#                         NAME  POPESTIMATE2019
# 0              United States        328239523
# 1                    Alabama          4903185
# 2                     Alaska           731545
# 3                    Arizona          7278717
# 4                   Arkansas          3017804
# 5                 California         39512223
# 6                   Colorado          5758736
# 7                Connecticut          3565287
# 8                   Delaware           973764
# 9       District of Columbia           705749
# 10                   Florida         21477737
# 11                   Georgia         10617423
# 12                    Hawaii          1415872
# 13                     Idaho          1787065
# 14                  Illinois         12671821
# 15                   Indiana          6732219
# 16                      Iowa          3155070
# 17                    Kansas          2913314
# 18                  Kentucky          4467673
# ...

# %%
census_df.shape
# Out:
# (53, 2)

# %%
census_df.count()
# Out:
# NAME               53
# POPESTIMATE2019    53
# dtype: int64

# %%
import pandas as pd

# %%
covid_death_file = "Resources/state_deaths_JanOct20.csv"
covid_death_df = pd.read_csv(covid_death_file)

# %%
covid_death_df.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
covid_death_df.columns
# Out:
# Index(['date', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %%
covid_death_df.drop(["fips"], axis=1, inplace=True)

# %%
covid_death_df.head()
# Out:
#          date       state  cases  deaths
# 0  2020-01-21  Washington      1       0
# 1  2020-01-22  Washington      1       0
# 2  2020-01-23  Washington      1       0
# 3  2020-01-24    Illinois      1       0
# 4  2020-01-24  Washington      1       0

# %%
covid_death_df.count()
# Out:
# date      12994
# state     12994
# cases     12994
# deaths    12994
# dtype: int64

# %%
state_group_by_death_df = covid_death_df.groupby(covid_death_df["state"])
state_group_by_death_df.head()
# Out:
#             date                     state  cases  deaths
# 0     2020-01-21                Washington      1       0
# 1     2020-01-22                Washington      1       0
# 2     2020-01-23                Washington      1       0
# 3     2020-01-24                  Illinois      1       0
# 4     2020-01-24                Washington      1       0
# ...          ...                       ...    ...     ...
# 1425  2020-03-28  Northern Mariana Islands      2       0
# 1480  2020-03-29  Northern Mariana Islands      2       0
# 1535  2020-03-30  Northern Mariana Islands      2       0
# 1590  2020-03-31  Northern Mariana Islands      2       0
# 1645  2020-04-01  Northern Mariana Islands      6       1
#
# [275 rows x 4 columns]

# %%
death_df.head(40)
# Out:
#         States       date  deaths
# 0      Alabama      April      30
# 1      Alabama     August      31
# 2      Alabama       July      31
# 3      Alabama       June      30
# 4      Alabama      March      19
# 5      Alabama        May      31
# 6      Alabama    October      19
# 7      Alabama  September      30
# 8       Alaska      April      30
# 9       Alaska     August      31
# 10      Alaska       July      31
# 11      Alaska       June      30
# 12      Alaska      March      20
# 13      Alaska        May      31
# 14      Alaska    October      19
# 15      Alaska  September      30
# 16     Arizona      April      30
# 17     Arizona     August      31
# 18     Arizona   February      29
# 19     Arizona    January       6
# 20     Arizona       July      31
# 21     Arizona       June      30
# 22     Arizona      March      31
# 23     Arizona        May      31
# 24     Arizona    October      19
# 25     Arizona  September      30
# ...

# %%
data
